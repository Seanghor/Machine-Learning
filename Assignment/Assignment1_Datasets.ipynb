# %% [markdown]
# <a href="https://colab.research.google.com/github/Seanghor/Machine-Learning/blob/main/Assignment/Assignment1_Datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assigment 1**

# %%
#1. Load the dataset
import sklearn  # machine learning
import numpy as np # computations
import pandas as pd # Data management
dataset = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/Fleet%20Data.csv")
print(dataset.head(10))  # To view the first 10 rows
# Out:
#     Parent Airline          Airline                      Aircraft Type  \
# 0  Aegean Airlines  Aegean Airlines                        Airbus A319
# 1  Aegean Airlines      Olympic Air                        Airbus A319
# 2  Aegean Airlines  Aegean Airlines                        Airbus A320
# 3  Aegean Airlines      Olympic Air                        Airbus A320
# 4  Aegean Airlines  Aegean Airlines                        Airbus A321
# 5  Aegean Airlines      Olympic Air                          ATR 42/72
# 6  Aegean Airlines  Aegean Airlines                          ATR 42/72
# 7  Aegean Airlines  Aegean Airlines                         Boeing 737
# 8  Aegean Airlines  Aegean Airlines  British Aerospace BAe 146/Avro RJ
# 9  Aegean Airlines      Olympic Air   De Havilland Canada DHC-8 Dash 8
#
#    Current  Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# 0      1.0     NaN       3.0    4.0     NaN       $90                  $90
# ...

# %%
#2. Dimension of dataset = (rows, columns)
dataset.shape
# Out:
# (1583, 11)

# %%
# describe the dataset
dataset.describe()
# Out:
#           Current      Future     Historic        Total      Orders  \
# count  859.000000  188.000000  1113.000000  1484.000000  348.000000
# mean    24.033760    3.382979    14.513028    24.955526   26.419540
# std     41.091234    4.656331    23.763373    46.651526   43.024179
# min      1.000000    1.000000     1.000000     1.000000    1.000000
# 25%      5.000000    1.000000     3.000000     4.000000    5.000000
# 50%     12.000000    2.000000     7.000000    11.000000   13.500000
# 75%     26.500000    4.000000    16.000000    27.000000   28.250000
# max    718.000000   38.000000   325.000000   952.000000  400.000000
#
#        Average Age
# count   820.000000
# mean     10.115000
# std       6.859362
# min       0.100000
# 25%       5.000000
# 50%       8.900000
# 75%      14.500000
# max      39.000000

# %%
# # Check the variable(Numerical / categorical)
numerical_variable= dataset.columns[dataset.dtypes != 'object']
numerical = dataset[numerical_variable].head(5)
print(numerical)
# print("*"*50+"\n")
# Out:
#    Current  Future  Historic  Total  Orders  Average Age
# 0      1.0     NaN       3.0    4.0     NaN         11.6
# 1      NaN     NaN       8.0    8.0     NaN          NaN
# 2     38.0     NaN       3.0   41.0     NaN          7.5
# 3      NaN     NaN       9.0    9.0     NaN          NaN
# 4      8.0     NaN       NaN    8.0     NaN         10.3

# %%
categorical_variable= dataset.columns[dataset.dtypes == 'object']
categorical= dataset[categorical_variable].head(5)
print(categorical)
# Out:
#     Parent Airline          Airline Aircraft Type Unit Cost  \
# 0  Aegean Airlines  Aegean Airlines   Airbus A319       $90
# 1  Aegean Airlines      Olympic Air   Airbus A319       $90
# 2  Aegean Airlines  Aegean Airlines   Airbus A320       $98
# 3  Aegean Airlines      Olympic Air   Airbus A320       $98
# 4  Aegean Airlines  Aegean Airlines   Airbus A321      $115
#
#   Total Cost (Current)
# 0                  $90
# 1                   $0
# 2               $3,724
# 3                   $0
# 4                 $919

# %%
# Missing values

dataset.isnull().head(5)    # check all
numerical_null = dataset[numerical_variable].isnull().head(5) # check null for numerical
categorical_null = dataset[categorical_variable].isnull().head(5) # check null for object
print(numerical_null)
print(categorical_null)
# Out:
#    Current  Future  Historic  Total  Orders  Average Age
# 0    False    True     False  False    True        False
# 1     True    True     False  False    True         True
# 2    False    True     False  False    True        False
# 3     True    True     False  False    True         True
# 4    False    True      True  False    True        False
#    Parent Airline  Airline  Aircraft Type  Unit Cost  Total Cost (Current)
# 0           False    False          False      False                 False
# 1           False    False          False      False                 False
# 2           False    False          False      False                 False
# 3           False    False          False      False                 False
# 4           False    False          False      False                 False

# %%
# Find out the percentage of missing values
# len(dataset)
dataset.isnull().sum() / len(dataset)
# dataset[numerical_variable].isnull().sum() / len(dataset)
# Out:
# Parent Airline          0.000000
# Airline                 0.000000
# Aircraft Type           0.000000
# Current                 0.457359
# Future                  0.881238
# Historic                0.296905
# Total                   0.062539
# Orders                  0.780164
# Unit Cost               0.022110
# Total Cost (Current)    0.017056
# Average Age             0.481996
# dtype: float64

# %%
# Replace

# dataset.fillna('Hor')  # This function is going to identify the missing value and replace that missing value with your 'Hor'
# dataset['Current'].replace(1,0).head(5) # replace 0 by 1 ;     1 => 0
# dataset.replace(1,'Hor').head(20)    #Replace 1 by Hor
dataset['Current'].replace([8,1],['HOR',0]).head(15)  # replace 8 by HOR and replace 1 bye 0
# Out:
# 0        0
# 1      NaN
# 2     38.0
# 3      NaN
# 4      HOR
# 5      2.0
# 6      NaN
# 7      NaN
# 8      NaN
# 9     12.0
# 10     NaN
# 11    26.0
# 12     NaN
# 13    10.0
# 14    71.0
# Name: Current, dtype: object

# %%
# # Create the rows and add it with the original dataset
# # Values of variable, instructions abut the variable

row_insert = pd.Series(['Seanghor Airline', 'Seanghor Airless', 'Airbus A9999', 99, 9, 99, 89, 9, '$99', '$999', 99.9],index = ['Parent Airline','Airline','Aircraft Type','Current','Future','Historic','Total','Orders','Unit Cost','Total Cost (Current)','Average Age'])

# %%
#  Series is used to create the row
dataset.append(row_insert, ignore_index=True)
# Out:
#         Parent Airline           Airline                     Aircraft Type  \
# 0      Aegean Airlines   Aegean Airlines                       Airbus A319
# 1      Aegean Airlines       Olympic Air                       Airbus A319
# 2      Aegean Airlines   Aegean Airlines                       Airbus A320
# 3      Aegean Airlines       Olympic Air                       Airbus A320
# 4      Aegean Airlines   Aegean Airlines                       Airbus A321
# ...                ...               ...                               ...
# 1579           WestJet           WestJet                        Boeing 767
# 1580           WestJet    WestJet Encore  De Havilland Canada DHC-8 Dash 8
# 1581          Wizz Air          Wizz Air                       Airbus A320
# 1582          Wizz Air          Wizz Air                       Airbus A321
# 1583  Seanghor Airline  Seanghor Airless                      Airbus A9999
#
# ...

# %%
# # Call the row
# # datasetname.iloc[] - we can call the specific row based on the index
# dataset.iloc[1]
dataset.iloc[1:11]
# dataset.iloc[ :11]
# Out:
#      Parent Airline          Airline                      Aircraft Type  \
# 1   Aegean Airlines      Olympic Air                        Airbus A319
# 2   Aegean Airlines  Aegean Airlines                        Airbus A320
# 3   Aegean Airlines      Olympic Air                        Airbus A320
# 4   Aegean Airlines  Aegean Airlines                        Airbus A321
# 5   Aegean Airlines      Olympic Air                          ATR 42/72
# 6   Aegean Airlines  Aegean Airlines                          ATR 42/72
# 7   Aegean Airlines  Aegean Airlines                         Boeing 737
# 8   Aegean Airlines  Aegean Airlines  British Aerospace BAe 146/Avro RJ
# 9   Aegean Airlines      Olympic Air   De Havilland Canada DHC-8 Dash 8
# 10         Aeroflot         Aeroflot                        Airbus A310
#
#     Current  Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# 1       NaN     NaN       8.0    8.0     NaN       $90                   $0
# ...

# %%
# # loc - to call the specific values,
# # index
dataset= dataset.set_index(dataset['Aircraft Type'])
dataset.loc['Boeing 737']  # call for specific information
# Out:
#                  Parent Airline                   Airline Aircraft Type  \
# Aircraft Type
# Boeing 737      Aegean Airlines           Aegean Airlines    Boeing 737
# Boeing 737             Aeroflot                  Aeroflot    Boeing 737
# Boeing 737             Aeroflot                    Pobeda    Boeing 737
# Boeing 737             Aeroflot          Rossiya Airlines    Boeing 737
# Boeing 737             Aeroflot           Aurora Airlines    Boeing 737
# ...                         ...                       ...           ...
# Boeing 737     Vietnam Airlines  Jetstar Pacific Airlines    Boeing 737
# Boeing 737     Virgin Australia          Virgin Australia    Boeing 737
# Boeing 737     Virgin Australia              Virgin Samoa    Boeing 737
# Boeing 737     Virgin Australia        Tigerair Australia    Boeing 737
# Boeing 737              WestJet                   WestJet    Boeing 737
#
#                Current  Future  Historic  Total  Orders Unit Cost  \
# Aircraft Type
# ...

# %%
# Rename
dataset.rename(columns = {'Aircraft Type' : '	Aircraft Name'}).head(5)
# Out:
#                 Parent Airline          Airline \tAircraft Name  Current  \
# Aircraft Type
# Airbus A319    Aegean Airlines  Aegean Airlines     Airbus A319      1.0
# Airbus A319    Aegean Airlines      Olympic Air     Airbus A319      NaN
# Airbus A320    Aegean Airlines  Aegean Airlines     Airbus A320     38.0
# Airbus A320    Aegean Airlines      Olympic Air     Airbus A320      NaN
# Airbus A321    Aegean Airlines  Aegean Airlines     Airbus A321      8.0
#
#                Future  Historic  Total  Orders Unit Cost Total Cost (Current)  \
# Aircraft Type
# Airbus A319       NaN       3.0    4.0     NaN       $90                  $90
# Airbus A319       NaN       8.0    8.0     NaN       $90                   $0
# Airbus A320       NaN       3.0   41.0     NaN       $98               $3,724
# Airbus A320       NaN       9.0    9.0     NaN       $98                   $0
# Airbus A321       NaN       NaN    8.0     NaN      $115                 $919
#
# ...

# %%
# Delete column
# dataset.drop('Future',axis = 1).head(5)      # axis = 1 => column, axis = 0 => row
dataset.drop(dataset.columns[1],axis = 1)  # delete columns at index 1
# Out:
#                                    Parent Airline  \
# Aircraft Type
# Airbus A319                       Aegean Airlines
# Airbus A319                       Aegean Airlines
# Airbus A320                       Aegean Airlines
# Airbus A320                       Aegean Airlines
# Airbus A321                       Aegean Airlines
# ...                                           ...
# Boeing 757                                WestJet
# Boeing 767                                WestJet
# De Havilland Canada DHC-8 Dash 8          WestJet
# Airbus A320                              Wizz Air
# Airbus A321                              Wizz Air
#
#                                                      Aircraft Type  Current  \
# Aircraft Type
# Airbus A319                                            Airbus A319      1.0
# Airbus A319                                            Airbus A319      NaN
# Airbus A320                                            Airbus A320     38.0
# ...

# %%
# Delete row
# axis 0 for row , axis 1 for columns
delete_row= dataset.drop(dataset.index[1]) # delete row at index 1
print(delete_row)
# dataset['Current'].unique()
# Out:
#                                    Parent Airline          Airline  \
# Aircraft Type
# Airbus A320                       Aegean Airlines  Aegean Airlines
# Airbus A320                       Aegean Airlines      Olympic Air
# Airbus A321                       Aegean Airlines  Aegean Airlines
# ATR 42/72                         Aegean Airlines      Olympic Air
# ATR 42/72                         Aegean Airlines  Aegean Airlines
# ...                                           ...              ...
# Boeing 757                                WestJet          WestJet
# Boeing 767                                WestJet          WestJet
# De Havilland Canada DHC-8 Dash 8          WestJet   WestJet Encore
# Airbus A320                              Wizz Air         Wizz Air
# Airbus A321                              Wizz Air         Wizz Air
#
#                                                      Aircraft Type  Current  \
# Aircraft Type
# ...
