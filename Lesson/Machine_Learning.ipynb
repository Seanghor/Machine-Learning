# %% [markdown]
# <a href="https://colab.research.google.com/github/Seanghor/Machine-Learning/blob/main/Lesson/Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Machine Learning")
# Out:
# Hello Machine Learning

# %% [markdown]
# **ML: 18-05-2022**

# %% [markdown]
# Scikit
#
# *   List item
# *   List item
#
#
# numpy

# %% [markdown]
# 1.   List item
# 2.   List item

# %%
import sklearn  # machine learning
import numpy as np # computation
import pandas as pd  # Data management

# %% [markdown]
#
# Machine learning is part of Data science => Data scicence we discussion about data => understand about algorithm + ttrying to see the result
#
# **Pre-processing**
# 1.   Load the dataset:
# 2.   Dimensions : find num of Row and Columns
# 3.   Check the variable(Numerical/categorical) : Check what type variable we have? numerical or gatagorical?
# 4.   Missing value: try to understand the misssing value
# 5.   Find out the percentage of missing **value**: How many percentage variable missed from original dataset
# 6.   Replace : If choose particular value it posible to replace, If identify missing value it possible to fill missing
# 7.   Fillupthe missing value
# 8.   Create the rows and add it with the original daataset
# 9.   Choose the exact rows from the dataset
# 10.  Rename the columns:
# 11.  Find the min, max, sum, count
# 12.  delete the rows and columns
# 13.  Unique values

# %%
#1. Load the dataset
import sklearn  #machine learning
import numpy as np #computation
import pandas as pd  # Data management
datasets = pd.read_csv("https://raw.githubusercontent.com/datasets/covid-19/main/data/time-series-19-covid-combined.csv")
datasets.head(5)
# Out:
#          Date Country/Region Province/State  Confirmed  Recovered  Deaths
# 0  2020-01-22    Afghanistan            NaN          0        0.0       0
# 1  2020-01-23    Afghanistan            NaN          0        0.0       0
# 2  2020-01-24    Afghanistan            NaN          0        0.0       0
# 3  2020-01-25    Afghanistan            NaN          0        0.0       0
# 4  2020-01-26    Afghanistan            NaN          0        0.0       0

# %%
# Dimention: rows and column
datasets.shape
# Out:
# (816, 9)

# %% [markdown]
# **20-05-2022**

# %% [markdown]
# Test from internet

# %%
# Code source: Jaques Grobler
# License: BSD 3 clause

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print("Coefficients: \n", regr.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
# descrice dataset
import sklearn  #machine learning
import numpy as np #computation
import pandas as pd  # Data management
datasets.describe()
# Out:
#               China            US  United_Kingdom         Italy        France  \
# count  8.160000e+02  8.160000e+02    8.160000e+02  8.160000e+02  8.160000e+02
# mean   1.696816e+05  2.814112e+07    5.363346e+06  3.571904e+06  5.623503e+06
# std    2.754920e+05  2.432460e+07    6.020675e+06  3.851434e+06  6.806034e+06
# min    5.480000e+02  1.000000e+00    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    9.318025e+04  5.247606e+06    3.164315e+05  2.521045e+05  2.481825e+05
# 50%    1.091465e+05  2.902645e+07    4.216773e+06  3.011124e+06  3.907140e+06
# 75%    1.194312e+05  4.292658e+07    7.644779e+06  4.654576e+06  7.076648e+06
# max    1.760211e+06  8.062512e+07    2.191696e+07  1.565984e+07  2.787427e+07
#
#             Germany         Spain          Iran
# count  8.160000e+02  8.160000e+02  8.160000e+02
# mean   3.685456e+06  3.375564e+06  2.667263e+06
# std    4.875119e+06  3.257851e+06  2.529457e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
# check the variable (numerical/ categorical)'
numerical_variable = datasets.columns[datasets.dtypes!='object']
datasets[numerical_variable].head(5)

categorical_variable = datasets.columns[datasets.dtypes!='object']
datasets[categorical_variable].head(5)
# Out:
#    China  US  United_Kingdom  Italy  France  Germany  Spain  Iran
# 0    548   1               0      0       0        0      0     0
# 1    643   1               0      0       0        0      0     0
# 2    920   2               0      0       2        0      0     0
# 3   1406   2               0      0       3        0      0     0
# 4   2075   5               0      0       3        0      0     0

# %%
# Missing value
datasets.isnull().sum()/len(datasets)
datasets[numerical_variable].isnull().sum()
datasets[numerical_variable].isnull().sum()/len(datasets)
# Out:
# China             0.0
# US                0.0
# United_Kingdom    0.0
# Italy             0.0
# France            0.0
# Germany           0.0
# Spain             0.0
# Iran              0.0
# dtype: float64

# %%
# Replace
# datasets['Confirmed'].replace(0, 1)
datasets.replace(0, "KIT")
datasets['Confirmed'].replace(['KIT',0]).head(15)
datasets.fillna('KIT')
# Out:
#               Date Country/Region Province/State  Confirmed Recovered  Deaths
# 0       2020-01-22    Afghanistan            KIT          0       0.0       0
# 1       2020-01-23    Afghanistan            KIT          0       0.0       0
# 2       2020-01-24    Afghanistan            KIT          0       0.0       0
# 3       2020-01-25    Afghanistan            KIT          0       0.0       0
# 4       2020-01-26    Afghanistan            KIT          0       0.0       0
# ...            ...            ...            ...        ...       ...     ...
# 231739  2022-04-12       Zimbabwe            KIT     247094       0.0    5460
# 231740  2022-04-13       Zimbabwe            KIT     247160       0.0    5460
# 231741  2022-04-14       Zimbabwe            KIT     247208       0.0    5462
# 231742  2022-04-15       Zimbabwe            KIT     247237       0.0    5462
# 231743  2022-04-16       Zimbabwe            KIT     247237       0.0    5462
#
# [231744 rows x 6 columns]

# %% [markdown]
# **Create row: **

# %%
# Create row:
# create the rows and add it with the original data
#value of variable , instruction about the variable 
row_insert=pd.Series(['2022-05-20','5','50','0','1','2','3','4','5'],index=['Data',['China'],['US'],['United_Kingdom'],['Italy'],['France'],['Germany'],['Spain'],['Iran']])

datasets =

# %% [markdown]
# **Call Row**

# %%
#  Call the row
#  datasetname.iloc - we can call the specific row based on the index
datasets.iloc[0]
datasets.iloc[1:5]
# datasets.iloc[5]
# Out:
#          Date Country/Region Province/State  Confirmed  Recovered  Deaths
# 1  2020-01-23    Afghanistan            NaN          0        0.0       0
# 2  2020-01-24    Afghanistan            NaN          0        0.0       0
# 3  2020-01-25    Afghanistan            NaN          0        0.0       0
# 4  2020-01-26    Afghanistan            NaN          0        0.0       0

# %%
datasets.iloc[3]
# Out:
# Date               2020-01-25
# Country/Region    Afghanistan
# Province/State            NaN
# Confirmed                   0
# Recovered                 0.0
# Deaths                      0
# Name: 3, dtype: object

# %%
# loc - to call the specific value
# Index
datasets = datasets.set_index(datasets['Date'])
datasets.loc['2020-01-22']
# Out:
#                   Date        Country/Region Province/State  Confirmed  \
# Date
# 2020-01-22  2020-01-22           Afghanistan            NaN          0
# 2020-01-22  2020-01-22               Albania            NaN          0
# 2020-01-22  2020-01-22               Algeria            NaN          0
# 2020-01-22  2020-01-22               Andorra            NaN          0
# 2020-01-22  2020-01-22                Angola            NaN          0
# ...                ...                   ...            ...        ...
# 2020-01-22  2020-01-22    West Bank and Gaza            NaN          0
# 2020-01-22  2020-01-22  Winter Olympics 2022            NaN          0
# 2020-01-22  2020-01-22                 Yemen            NaN          0
# 2020-01-22  2020-01-22                Zambia            NaN          0
# 2020-01-22  2020-01-22              Zimbabwe            NaN          0
#
#             Recovered  Deaths
# Date
# 2020-01-22        0.0       0
# 2020-01-22        0.0       0
# ...

# %%
datasets = datasets.set_index(datasets['Country/Region'])
datasets.loc['Cambodia']
# Out:
#                       Date Country/Region Province/State  Confirmed  \
# Country/Region
# Cambodia        2020-01-22       Cambodia            NaN          0
# Cambodia        2020-01-23       Cambodia            NaN          0
# Cambodia        2020-01-24       Cambodia            NaN          0
# Cambodia        2020-01-25       Cambodia            NaN          0
# Cambodia        2020-01-26       Cambodia            NaN          0
# ...                    ...            ...            ...        ...
# Cambodia        2022-04-12       Cambodia            NaN     135980
# Cambodia        2022-04-13       Cambodia            NaN     136013
# Cambodia        2022-04-14       Cambodia            NaN     136013
# Cambodia        2022-04-15       Cambodia            NaN     136032
# Cambodia        2022-04-16       Cambodia            NaN     136044
#
#                 Recovered  Deaths
# Country/Region
# Cambodia              0.0       0
# Cambodia              0.0       0
# ...

# %% [markdown]
# **Rename Function**

# %%
# rename
datasets.rename(columns={'Country/Region': 'Country'}).head(5)
# Out:
#                       Date      Country Province/State  Confirmed  Recovered  \
# Country/Region
# Afghanistan     2020-01-22  Afghanistan            NaN          0        0.0
# Afghanistan     2020-01-23  Afghanistan            NaN          0        0.0
# Afghanistan     2020-01-24  Afghanistan            NaN          0        0.0
# Afghanistan     2020-01-25  Afghanistan            NaN          0        0.0
# Afghanistan     2020-01-26  Afghanistan            NaN          0        0.0
#
#                 Deaths
# Country/Region
# Afghanistan          0
# Afghanistan          0
# Afghanistan          0
# Afghanistan          0
# Afghanistan          0
